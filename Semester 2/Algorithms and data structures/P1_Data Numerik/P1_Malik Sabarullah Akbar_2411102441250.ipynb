# %% [markdown]
# # **LAPORAN PRAKTIKUM 1**
# ## **ALGORITMA & STRUKTUR DATA – DATA NUMERIK**
# ### **Program Studi Teknik Informatika – Universitas Muhammadiyah Kalimantan Timur**
#
# ---

# %% [markdown]
# ## Identitas Mahasiswa
# NAMA    : Malik Sabarullah Akbar
#
# NIM     : 2411102441250
#
# KELAS   : B
#
# ---

# %% [markdown]
# ## **1. Pendahuluan**
# ### **1.1 Latar Belakang**
# Dalam pemrograman, data numerik sangat penting karena digunakan dalam berbagai operasi matematika dan logika. Python menyediakan beberapa tipe data numerik seperti **integer (`int`)**, **float (`float`)**, dan **complex (`complex`)**. Praktikum ini bertujuan untuk memahami bagaimana cara kerja tipe data numerik di Python serta bagaimana penggunaannya dalam program.
#
# ### **1.2 Tujuan Praktikum**
# Mahasiswa diharapkan mampu:
# ^ Memahami konsep dasar Python 3.
# ^ Mengenal dan menggunakan tipe data numerik (`int`, `float`, `complex`).
# ^ Menjalankan perintah dasar Python untuk operasi bilangan.
# ^ Mengonversi data numerik dari satu bentuk ke bentuk lain.
# ^ Menganalisis hasil dari operasi numerik menggunakan Python.
#
# 💡 **Tips:**
# - Jangan hanya menjalankan kode, tetapi pahami setiap barisnya!
# - Pastikan laporan memiliki **analisis yang jelas** terhadap hasil percobaan.
# - Gunakan Markdown untuk menulis deskripsi di dalam Jupyter Notebook agar lebih rapi.
#
# ---
#
# ## **2. Materi Praktikum**
# ### **2.1 Review Python 3**
# Python adalah bahasa pemrograman tingkat tinggi yang mudah dipelajari dan digunakan. Beberapa tipe data utama dalam Python adalah:
# - **Numbers (Angka) → `int`, `float`, `complex`**
# - **String (Teks) → `str`**
# - **List (Daftar)**
# - **Tuple (Urutan tidak bisa diubah)**
# - **Dictionary (Kumpulan data berbasis key-value)**
#
# ### **2.2 Tipe Data Numerik dalam Python**
# Python memiliki tiga tipe data numerik utama:
# 1. **Integer (`int`)**
#    - Bilangan bulat seperti `10`, `-5`, `1000`.
#    - Tidak memiliki koma desimal.
#    - Bisa dicek jumlah bit-nya dengan `.bit_length()`.
#
# 2. **Float (`float`)**
#    - Bilangan desimal seperti `3.14`, `-0.5`, `10.0`.
#    - Digunakan untuk angka pecahan.
#
# 3. **Complex (`complex`)**
#    - Bilangan kompleks seperti `3 + 4j`, di mana `3` adalah bagian real dan `4j` adalah bagian imajiner.
#    - Python secara otomatis mengenali bilangan kompleks dengan `j` sebagai imajiner.
#
# ---

# %%
# Jelaskan apa yang anda pahami dari penjelasan di atas

# 2.1
    # String
    # menurut saya, string adalah tipe data yang digunakan untuk menyimpan karakter atau teks
    
    # list
    # menurut saya, list adalah tipe data yang digunakan untuk menyimpan beberapa data sekaligus dalam satu variabel
    
    # tuple
    # sedangkan tuple adalah kebalikan dari list, yaitu tipe data yang digunakan untuk menyimpan beberapa data sekaligus dalam satu variabel, namun data yang disimpan tidak dapat diubah
    
    # dictionary
    # menurut saya, dictionary adalah tipe data yang digunakan untuk menyimpan data dalam bentuk pasangan key-value

# 2.2
# 1.Integer
# menurut saya, integer merupakan tipe data bilangan bulat yang tidak memiliki koma
# dan method .bit_length() adalah method yang digunakan untuk menghitung jumlah bit yang digunakan untuk merepresentasikan bilangan tersebut
# contoh,jika angka 10 direpresentasikan dalam bit, maka akan menggunakan 4 bit, yaitu 1010
# jika angka 100 direpresentasikan dalam bit, maka akan menggunakan 7 bit, yaitu 1100100

# 2.Float
# menurut saya, float merupakan tipe data bilangan pecahan yang memiliki koma

# 3.Complex
# menurut saya, complex merupakan tipe data bilangan kompleks yang terdiri dari bilangan real dan bilangan imajiner
num = 1 + 2j
print(num.real) # 1.0
print(num.imag) # 2.0
print(complex(1, 2)) # 1+2j

import random

print(random.randint(1, 10))
print(random.random())
print(random.uniform(1, 10))
print(random.choice([1, 52, 33, 14, 5]))
# Out:
# 1.0
# 2.0
# (1+2j)
# 1
# 0.7689225159526847
# 6.673400272178886
# 14

# %% [markdown]
# ## **3. Tugas Pendahuluan**
# Sebelum memulai praktikum, jawab pertanyaan berikut:
#
# 1. **Jelaskan fungsi dan parameter dari sintaks berikut:**
#    - `int(x, base)`
#    - `float(x)`
#    - `complex([real, imag])`
#
# 2. **Sebutkan metode lain untuk merepresentasikan tipe data numerik selain `int`, `float`, dan `complex`!**
#    *Petunjuk: Bisa menggunakan `decimal` atau `fractions` dari modul Python.*
#
# ---

# %%
# 1.
    # jelaskan fungsi dari int(x,base)
    # fungsi dari int(x,base) adalah mengubah bilangan x menjadi bilangan integer dengan base tertentu
    # contoh, int('10',2) akan mengubah bilangan 10 yang dalam base 10 menjadi bilangan 2 dan hasilnya adalah 2

    # number = int('10',2)
    # print(number) -> 2
    
    # float(x)
    # fungsi dari float(x) adalah mengubah bilangan x menjadi bilangan float atau bilangan pecahan
    
    # complex([real,imag])
    # fungsi dari complex([real,imag]) adalah mengubah bilangan real dan bilangan imajiner menjadi bilangan kompleks
    # contoh, complex(1,2) akan mengubah bilangan 1 dan 2 menjadi bilangan kompleks 1+2j
    
# 2.
    # method decimal() adalah method yang digunakan untuk mengubah bilangan integer menjadi bilangan desimal
    # contoh, jika angka 10 direpresentasikan dalam desimal, maka akan menjadi 10
    # jika angka 100 direpresentasikan dalam desimal, maka akan menjadi 100
    
    # method fraction() adalah method yang digunakan untuk mengubah bilangan integer menjadi bilangan pecahan
    # contoh, jika angka 10 direpresentasikan dalam pecahan, maka akan menjadi 10/1 atau 10 
    # jika angka 100 direpresentasikan dalam pecahan, maka akan menjadi 100/1 atau 100

import decimal
import fractions

print(decimal.Decimal(0.2))
print(decimal.Decimal(120.5))
print(decimal.Decimal(120))

print("~" * 20)
print(fractions.Fraction(1.5))
print(fractions.Fraction(120))
# Out:
# 0.200000000000000011102230246251565404236316680908203125
# 120.5
# 120
# ~~~~~~~~~~~~~~~~~~~~
# 3/2
# 120

# %% [markdown]
# ## **4. Percobaan & Latihan**
# **Instruksi:**
# - Buat program Python berdasarkan langkah-langkah di bawah ini.
# - Eksekusi setiap kode dan analisis hasilnya.
# - Tuliskan output yang dihasilkan.
#
# ### **4.1 Latihan 1 – Operasi Numerik Dasar**
# <img src="1.jpg" width="550px" alt="Deskripsi Gambar" />
#
# **Analisis:**
# - Apa hasil dari setiap operasi di atas?
# - Apakah tipe data berubah setelah dikonversi dengan `int()` atau `float()`?
#
# ---

# %%
# Ketikan kode dan penjelasan disini!
nim = 2411102441250

print(len(str(nim)))

x = 12
y = 50

Ha = x + y
print(Ha)

Hb = Ha + 10.5
print("Hb : ", Hb)

Hc = int(Hb)
print("Hc : ", Hc)

Hd = Ha / Hb
print("Hd : ", Hd)

print(isinstance(Hd, int))
print(isinstance(Hd, float))

# Apakah tipe data berubah setelah dikonversi dengan `int()` atau `float()`?  Ya
# mengapa? karena int() hanya mengambil angka bulat saja sedangkan float() mengambil angka desimal
# Out:
# 13
# 62
# Hb :  72.5
# Hc :  72
# Hd :  0.8551724137931035
# False
# True

# %% [markdown]
# ### **4.2 Latihan 2 – Menghitung Panjang Bit Bilangan Integer**
# <img src="2.jpg" width="550px" alt="Deskripsi Gambar" />
#
# **Analisis:**
# - Berapa jumlah bit yang digunakan untuk setiap bilangan?
# - Apa perbedaan antara angka besar dan kecil dalam penggunaan bit?
#
# ---

# %%
# Ketikan kode dan penjelasan disini!
print((999).bit_length())
print((998).bit_length())
print((99).bit_length())
print((11).bit_length())
print((16).bit_length())

# apa perbedaan antara angka besar dan angka kecil dalam penggunaan bit_length()? 
# angka besar membutuhkan bit lebih banyak
# sedangkan angka kecil membutuhkan bit lebih sedikit
# Out:
# 10
# 10
# 7
# 4
# 5

# %% [markdown]
# ### **4.3 Latihan 3 – Representasi Bilangan dalam Format Lain**
# <img src="3.jpg" width="550px" alt="Deskripsi Gambar" />
#
# **Analisis:**
# - Apa hasil dari konversi angka 555 ke biner, hex, dan oktal?
# - Bagaimana cara kerja konversi ini dalam Python?
#
# ---

# %%
# Ketikan kode dan penjelasan disini!
i = 30
print(f"Hasil Perubahan angka ke Binary : {bin(i)}")
print(f"Hasil Perubahan angka ke Hexadecimal : {hex(i)}")
print(f"Hasil Perubahan angka ke Octal : {oct(i)}")

# bagaimana cara kerja fungsi bin(), hex(), dan oct()?
# bin() digunakan untuk mengubah angka menjadi binary
# hex() digunakan untuk mengubah angka menjadi hexadecimal
# oct() digunakan untuk mengubah angka menjadi octal
# Out:
# Hasil Perubahan angka ke Binary : 0b11110
# Hasil Perubahan angka ke Hexadecimal : 0x1e
# Hasil Perubahan angka ke Octal : 0o36

# %% [markdown]
# ### **4.4 Studi Literasi**
# <img src="4.jpg" width="750px" alt="Deskripsi Gambar" />

# %%
# Ketikan penjelasan disini!

# 1.
    # Integer
    # Integer adalah tipe data bilangan bulat yang tidak memiliki koma
    # contoh
x = 10
print(x)

    # Float
    # Float adalah tipe data bilangan pecahan yang memiliki koma
    # contoh
y = 10.5
print(y)

    # Complex
    # Complex adalah tipe data bilangan kompleks yang terdiri dari bilangan real dan bilangan imajiner
    # contoh
z = 1 + 2j
print(z)
print(z.real)
print(z.imag)

    # Operasi Numerik
    # Operasi numerik adalah operasi yang digunakan untuk melakukan operasi matematika
    # contoh
a = 10
b = 20
c = a + b
print(c)

    # Method Bit_length()
    # Method bit_length() adalah method yang digunakan untuk menghitung jumlah bit yang digunakan untuk merepresentasikan bilangan tersebut
    # contoh
d = 10
print(d.bit_length())

    # Hasilnya sama dengan yang dijelaskan di atas


# 2.
    # Apa saja yang saya pelajari?
    # Saya telah mempelajari tentang tipe data numerik, operasi numerik, method bit_length(),int(), float(), dan complex()
    
    # Contoh penerapan Tipe Data Numerik dalam programan
a = 10
b = 20
c = a + b
print(c)

    # contoh kasus sederhana kasus nyata di mana tipe data numerik digunakan
    # Penggunaan saat membuat program kalkulator
    # contoh
num1 = 10
num2 = 20
print("1. Penjumlahan : ",num1+num2)
print("2. Pengurangan : ",num1 - num2)
print("3. Perkalian : ",num1*num2)


# 3.
    # web : https://www.w3schools.com/python/default.asp 21.2.2025
# Out:
# 10
# 10.5
# (1+2j)
# 1.0
# 2.0
# 30
# 4
# 30
# 1. Penjumlahan :  30
# 2. Pengurangan :  -10
# 3. Perkalian :  200

# %% [markdown]
# ---
#
# ## **5. Format File Tugas**
# - **Tugas dikumpulkan dalam format Jupyter Notebook (`.ipynb`).**
# - Gunakan format Markdown untuk dokumentasi di dalam notebook.
# - Pastikan setiap bagian memiliki heading (`#` untuk judul, `##` untuk subjudul).
# - **File tugas diberi nama: `P1_Nama_NIM.ipynb`**
# - **🚨 <span style="color:darkred; font-weight:bold; font-size:18px;">PLAGIAT AKAN DIBERI SANKSI TANPA AMPUN! 🚨</span>**
